# %%
import os
import pandas as pd
import numpy as np

# %%
df_dict = pd.read_excel('supplysim_price_data.xlsx', sheet_name = None)

print(df_dict)
# Out:
# {'0x-ZRX':       timestamp     price
# 0    2017-08-16  0.111725
# 1    2017-08-17  0.223022
# 2    2017-08-18  0.205558
# 3    2017-08-19  0.294578
# 4    2017-08-20  0.471296
# ...         ...       ...
# 2156 2023-07-12  0.210632
# 2157 2023-07-13  0.209915
# 2158 2023-07-14  0.225763
# 2159 2023-07-15  0.218251
# 2160 2023-07-16  0.222999
#
# [2161 rows x 2 columns], '1inch Network-1INCH':      timestamp     price
# 0   2020-12-25  1.602781
# 1   2020-12-26  2.318946
# 2   2020-12-27  1.597744
# 3   2020-12-28  1.064454
# 4   2020-12-29  1.110460
# ..         ...       ...
# 929 2023-07-12  0.314283
# 930 2023-07-13  0.324994
# 931 2023-07-14  0.349574
# 932 2023-07-15  0.335299
# 933 2023-07-16  0.369158
#
# [934 rows x 2 columns], 'Aave-AAVE':       timestamp      price
# 0    2020-10-02   0.519235
# 1    2020-10-03   0.526085
# 2    2020-10-04   0.528101
# 3    2020-10-05   0.528101
# 4    2020-10-06   0.528101
# ...         ...        ...
# 1013 2023-07-12  73.379941
# ...

# %%
for k,v in df_dict.items():
    v.to_csv(f'singledata/{k}_price.csv', index = False, encoding='utf-8')

# %%
os.listdir('singledata')
# Out:
# ['Coin98-C98_price.csv',
#  'Euler Finance-EUL_price.csv',
#  'BITTO-BITTO_price.csv',
#  'Luna-LUNA_price.csv',
#  'Ronin-RON_price.csv',
#  'TrueFi-TRU_price.csv',
#  'BENQI-QI1_price.csv',
#  'Illuvium-ILV_price.csv',
#  'JOE-JOE_price.csv',
#  'SPACE ID-ID-R2_price.csv',
#  'Uniswap-UNI-R2_price.csv',
#  'Zero Exchange-ZERO1_price.csv',
#  'Idle-IDLE_price.csv',
#  'Radiant capital-RDNT_price.csv',
#  'Stargate Finance-STG-R2_price.csv',
#  'VELOREX-VEX1_price.csv',
#  'Polkadot-DOT_price.csv',
#  'Seal Finance-SEAL_price.csv',
#  'Balancer-BAL_price.csv',
#  'Convex Finance-CONVEX_price.csv',
#  'SuperRare-SUPERRARE_price.csv',
#  'Premia-PREMIA_price.csv',
#  'Tornado Cash-TORN_price.csv',
#  'CANTO-CANTO_price.csv',
#  'PoolTogether-POOL_price.csv',
#  'SwftCoin-SWFTC_price.csv',
#  'Dogecoin-DOGE_price.csv',
#  'LooksRare-LOOKS_price.csv',
#  'Solana-SOL_price.csv',
#  'GMX-GMX_price.csv',
#  'SUI-SUI_price.csv',
#  'Aptos-APT_price.csv',
#  'FIO Protocol-FIO_price.csv',
# ...

# %%
os.listdir('../')
# Out:
# ['chartData_Polygon_matic-network.csv',
#  'matic-usd-max.csv',
#  'chartData_Polygon_matic-network.xlsx',
#  'SupplySimulation.ipynb',
#  'supplysim.py',
#  'X30.csv',
#  'data']
